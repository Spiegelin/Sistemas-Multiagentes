# %%
from IPython import display
display.clear_output()

import supervision as sv
import ultralytics
import cv2
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.15  Python-3.10.11 torch-2.0.1+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Setup complete  (16 CPUs, 15.4 GB RAM, 797.8/930.8 GB disk)

# %%
import os
cwd = os.getcwd()
HOME = os.path.join(cwd, '..')
os.environ['ROBOFLOW_API_KEY'] = 'ZRkp8AsIaXsO6H7S4Mgu'

# %%
import os
import dotenv
from roboflow import Roboflow

cwd = os.getcwd()
env_path = os.path.join(HOME, '.env')
dotenv.load_dotenv(dotenv_path=env_path)

ROBOFLOW_API_KEY = os.environ.get('ROBOFLOW_API_KEY')

dataset_path = os.path.join(HOME, 'datasets', 'naranja-yzbwc')

rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("multiagentes-zgh24").project("naranja-yzbwc")
dataset = project.version(1).download(model_format="yolov8", location=dataset_path)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.15, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\testo\..\datasets\naranja-yzbwc in yolov8:: 100%|██████████| 38/38 [00:00<00:00, 1461.35it/s]

# %%
# !yolo task=detect mode=train model=weights/yolo/yolov8n.pt data="modelo/datasets/naranja-yzbwc/data.yaml" epochs=25 imgsz=640 plots=True
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.2.82 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.11 torch-2.0.1+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# ...
