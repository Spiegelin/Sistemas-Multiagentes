# %%
# !nvidia-smi
# Out:
# Mon Sep  2 07:57:22 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.81                 Driver Version: 560.81         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   56C    P3             23W /   89W |     408MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196


from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Setup complete  (16 CPUs, 15.4 GB RAM, 903.4/930.8 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZRkp8AsIaXsO6H7S4Mgu")
project = rf.workspace("multiagentes-zgh24").project("proyecto-x3v5s")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# [WinError 2] El sistema no puede encontrar el archivo especificado: 'c:\\Users\\luisf\\OneDrive\\Documentos\\Coding\\Tec\\Sistemas multiagentes con graficas computacionales\\Prueba1/datasets'
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1
# La sintaxis del comando no es correcta.
# C:\Users\luisf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Proyecto-1 in yolov8:: 100%|██████████| 990/990 [00:00<00:00, 1534.88it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data="C:/Users/luisf/OneDrive/Documentos/Coding/Tec/Sistemas multiagentes con graficas computacionales/Prueba1/Proyecto-1/data.yaml" epochs=50 imgsz=800 plots=True
# Out:
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1
# C:\Users\luisf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# New https://pypi.org/project/ultralytics/8.2.86 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1

# %%
# %cd {HOME}

# !yolo task=detect mode=val model="C:/Users/luisf/OneDrive/Documentos/Coding/Tec/Sistemas multiagentes con graficas computacionales/Prueba1/runs/detect/train/weights/best.pt" data="C:/Users/luisf/OneDrive/Documentos/Coding/Tec/Sistemas multiagentes con graficas computacionales/Prueba1/Proyecto-1/data.yaml"
# Out:
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# val: Scanning C:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1\Proyecto-1\valid\labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|██████████| 59/59 [00:00<?, ?it/s]
# val: Scanning C:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\Prueba1\Proyecto-1\valid\labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|██████████| 59/59 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/4 [00:00<?, ?it/s]
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model="C:/Users/luisf/OneDrive/Documentos/Coding/Tec/Sistemas multiagentes con graficas computacionales/Prueba1/runs/detect/train/weights/best.pt" conf=0.25 source="C:/Users/luisf/OneDrive/Documentos/Coding/Tec/Sistemas multiagentes con graficas computacionales/Prueba1/Proyecto-1/test/images" save=True
# Out:
# c:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\dinoo
# This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 C:\Users\luisf\OneDrive\Documentos\Coding\Tec\Sistemas multiagentes con graficas computacionales\dinoo\qqq-1\test\images\Captura-de-pantalla-2024-09-01-133303_jpg.rf.c45b706bebe49c05a429cf41b672ed0b.jpg: 800x800 10 trees, 375.1ms
# Speed: 6.0ms preprocess, 375.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs\detect\predict
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = 'runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path) 
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 base_path = 'runs/detect/'
#       7 # List all directories that start with 'predict' in the base path
# ----> 8 subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
#       9               if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]
#      11 # Find the latest folder by modification time
#      12 latest_folder = max(subfolders, key=os.path.getmtime)
#
# NameError: name 'os' is not defined
